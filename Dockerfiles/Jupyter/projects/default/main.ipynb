# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# After adding a new uv project under `/workspace`, run the next cell to register its Jupyter kernel without restarting the container. The project must include `ipykernel`, for example `uv add --dev ipykernel`.

# %%
# !jupyter-register-uv-kernels
